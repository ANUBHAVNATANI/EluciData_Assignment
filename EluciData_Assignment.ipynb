# %%
# !pip install cmapPy
# Out:
# Requirement already satisfied: cmapPy in /usr/local/lib/python3.6/dist-packages (4.0.1)
# Requirement already satisfied: h5py>=2.6.0 in /usr/local/lib/python3.6/dist-packages (from cmapPy) (2.10.0)
# Requirement already satisfied: requests>=2.13.0 in /usr/local/lib/python3.6/dist-packages (from cmapPy) (2.23.0)
# Requirement already satisfied: pandas>=0.18 in /usr/local/lib/python3.6/dist-packages (from cmapPy) (1.1.4)
# Requirement already satisfied: numpy>=1.11.2 in /usr/local/lib/python3.6/dist-packages (from cmapPy) (1.18.5)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from cmapPy) (1.15.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.13.0->cmapPy) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.13.0->cmapPy) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.13.0->cmapPy) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.13.0->cmapPy) (2.10)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.18->cmapPy) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.18->cmapPy) (2018.9)

# %%
import numpy as np
import pandas as pd
import cmapPy.pandasGEXpress.parse as cmapPandas
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %%
# !unzip data_analyst_intern-20201121T181639Z-001.zip
# Out:
# Archive:  data_analyst_intern-20201121T181639Z-001.zip
# replace data_analyst_intern/type1_IFN.docx? [y]es, [n]o, [A]ll, [N]one, [r]ename: N

# %%
data_path = "./data_analyst_intern/PAAD.gct"

# %%
#gct file contains col meta data and row meta data
dataset = cmapPandas.parse(data_path)
row_meta_data = dataset.row_metadata_df
col_meta_data = dataset.col_metadata_df
data = dataset.data_df

# %%
#dataset info
row_meta_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18465 entries, SLC35E2 to psiTPTE22
# Empty DataFrame

# %%
col_meta_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 183 entries, aab1-Primary solid Tumor to aapl-Primary solid Tumor
# Columns: 124 entries, participant_id to year_of_tobacco_smoking_onset
# dtypes: float64(49), int64(10), object(65)
# memory usage: 183.7+ KB

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18465 entries, SLC35E2 to psiTPTE22
# Columns: 183 entries, aab1-Primary solid Tumor to aapl-Primary solid Tumor
# dtypes: float32(183)
# memory usage: 13.7+ MB

# %%
row_meta_data.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [SLC35E2, A1BG, A1CF, A2BP1, A2LD1]

# %%
col_meta_data.head()
# Out:
# chd                      participant_id  ... year_of_tobacco_smoking_onset
# cid                                      ...
# aab1-Primary solid Tumor           aab1  ...                        1962.0
# aab4-Primary solid Tumor           aab4  ...                           NaN
# aab6-Primary solid Tumor           aab6  ...                           NaN
# aab8-Primary solid Tumor           aab8  ...                           NaN
# aab9-Primary solid Tumor           aab9  ...                           NaN
#
# [5 rows x 124 columns]

# %%
data.head()
# Out:
# cid      aab1-Primary solid Tumor  ...  aapl-Primary solid Tumor
# rid                                ...
# SLC35E2                      7.45  ...                      9.05
# A1BG                         6.40  ...                      6.90
# A1CF                         4.70  ...                      2.00
# A2BP1                       -1.00  ...                       NaN
# A2LD1                        7.50  ...                      6.70
#
# [5 rows x 183 columns]

# %%
col_meta_data.shape
# Out:
# (183, 124)

# %%
#As we can see there are a lot of columns in the col_meta_data part
#As if columns contains constant values that is of no use we need to find if there are any columns that contains contant values we can drop them and not take them into consideration

# %%
def findUniqueCols(data):
  arr = []
  for col in data.columns:
    if len(data[col].unique())<2:
      arr.append(col)
  print("Number of columns with constant values "+str(len(arr)))
  return arr

# %%
def dropConstCols(data):
  col_list = findUniqueCols(data)
  data = data.drop(col_list,axis=1)
  return data

# %%
#give some showcase
#drop columns which have unique values
col_meta_data = dropConstCols(col_meta_data)
# Out:
# Number of columns with constant values 41

# %%
col_meta_data.shape
# Out:
# (183, 83)

# %%
#rid gives us the types of RNA sequence
row_meta_data.shape
# Out:
# (18465, 0)

# %%
#there are 18465 types of rna sequence

# %%
def findMissingVals(data):
  missing_val_count = data.isnull().sum().sum()
  print("Total missing Values in data "+str(missing_val_count))

# %%
findMissingVals(data)
# Out:
# Total missing Values in data 134954

# %%
#there are a lot of missing values we need to replace these value for good results

# %%
def replaceMissingValues(data):
  from sklearn.impute import SimpleImputer
  imputer = SimpleImputer()
  imputed_data = pd.DataFrame(imputer.fit_transform(data))
  imputed_data.columns = data.columns
  imputed_data.index = data.index
  return imputed_data

# %%
imputed_data = replaceMissingValues(data)

# %%
#set the participent id

# %%
imputed_data = imputed_data.rename(columns=col_meta_data.participant_id).T
imputed_data.head()
# Out:
# rid   SLC35E2  A1BG  A1CF     A2BP1  ...   ZYX  ZZEF1  ZZZ3  psiTPTE22
# cid                                  ...
# aab1     7.45   6.4   4.7 -1.000000  ...  12.9   10.1   9.3        5.5
# aab4     8.10   5.8   5.7  1.100000  ...  12.4    9.8   8.9        4.5
# aab6     7.20   6.4   3.0  7.577068  ...  13.5    9.8   9.2        4.7
# aab8     8.00   5.8   5.1  7.728812  ...  12.5    9.7   9.3        6.4
# aab9     7.65   6.7   4.4  0.100000  ...  13.0   10.1   9.2        4.9
#
# [5 rows x 18465 columns]

# %%
#now lets merge both the data to get a final dataset

# %%
cols_merge = ['sample_type', 'mRNAseq_cluster','adenocarcinoma_invasion', 'vital_status', 'maximum_tumor_dimension', 'pathologic_stage', 'pathologic_m', 'pathologic_n', 'pathologic_t']

# %%
col_meta_data = col_meta_data.set_index('participant_id')
for cols in cols_merge:
  imputed_data[cols] = col_meta_data[cols]

# %%
imputed_data.head()
# Out:
# rid   SLC35E2  A1BG  A1CF  ...  pathologic_m  pathologic_n  pathologic_t
# cid                        ...
# aab1     7.45   6.4   4.7  ...            m0            n1            t3
# aab4     8.10   5.8   5.7  ...            m0            n1            t2
# aab6     7.20   6.4   3.0  ...            m0            n0            t3
# aab8     8.00   5.8   5.1  ...            m0            n1            t3
# aab9     7.65   6.7   4.4  ...            m0            n1            t3
#
# [5 rows x 18474 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
for i in dtypes.iteritems():
  if i[1]=='object':
    col_name = i[0]
    imputed_data[col_name] = imputed_data[col_name].astype('|S')
    imputed_data[col_name] = le.fit_transform(imputed_data[col_name])

# %%
imputed_data.head()
# Out:
# rid   SLC35E2  A1BG  A1CF  ...  pathologic_m  pathologic_n  pathologic_t
# cid                        ...
# aab1     7.45   6.4   4.7  ...             0             1             3
# aab4     8.10   5.8   5.7  ...             0             1             2
# aab6     7.20   6.4   3.0  ...             0             0             3
# aab8     8.00   5.8   5.1  ...             0             1             3
# aab9     7.65   6.7   4.4  ...             0             1             3
#
# [5 rows x 18474 columns]

# %%
#get the varince of the data

# %%
from sklearn.preprocessing import StandardScaler
std = StandardScaler().fit_transform(imputed_data.drop(columns=cols_merge))

# %%
#Applying PCA
from sklearn.decomposition import PCA
pca = PCA(n_components=120)
y = pca.fit_transform(std)

# %%
cumulative_variance_ratio = (pca.explained_variance_ratio_.cumsum())*100

explained_variance_ratio = round(pca.explained_variance_ratio_.sum()*100, 2)

plt.bar(range(120), cumulative_variance_ratio, label='Cumulative Sum of Explained Varaince Ratio')
plt.title(f"{explained_variance_ratio}% of variance is explained by the fisrt {120} principle component ");

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=3)
x_r  = pca.fit_transform(std)
Y=imputed_data['sample_type']
from mpl_toolkits.mplot3d import Axes3D
plt.clf()
fig = plt.figure(1, figsize=(10,6 ))
ax = Axes3D(fig, elev=-150, azim=110,)
ax.scatter(x_r[:, 0], x_r[:, 1], x_r[:, 2],cmap=plt.cm.Paired,linewidths=10)
ax.set_title("First three PCA directions")
ax.set_xlabel("1st eigenvector")
ax.w_xaxis.set_ticklabels([])
ax.set_ylabel("2nd eigenvector")
ax.w_yaxis.set_ticklabels([])
ax.set_zlabel("3rd eigenvector")
ax.w_zaxis.set_ticklabels([])
# Out:
# []

# %%
#Removal of the neuro encdrocrine ones

# %%
#########Fix

# %%
imputed_data = imputed_data[imputed_data['adenocarcinoma_invasion']==1]
imputed_data.shape
# Out:
# (182, 18474)

# %%
ifn_data = pd.read_csv("./data_analyst_intern/type1_IFN.txt",header=None)

# %%
ifn_data.head()
# Out:
#        0
# 0  IFIT1
# 1  IFI44
# 2  IFIT3
# 3    MX2
# 4   OAS1

# %%
ifn_data.columns = ['ifn_info']

# %%
ifn_data.head()
# Out:
#   ifn_info
# 0    IFIT1
# 1    IFI44
# 2    IFIT3
# 3      MX2
# 4     OAS1

# %%
# !pip install gsva
# Out:
# Collecting gsva
#   Downloading https://files.pythonhosted.org/packages/c9/5b/dea37b86c9ac442579f7acdf538d04b077b81cf24da8455f204991e9882c/GSVA-1.0.6-py3-none-any.whl
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from gsva) (1.1.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas->gsva) (2.8.1)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.6/dist-packages (from pandas->gsva) (1.18.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas->gsva) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.7.3->pandas->gsva) (1.15.0)
# Installing collected packages: gsva
# Successfully installed gsva-1.0.6

# %%
imputed_data.head()
# Out:
# rid   SLC35E2  A1BG  A1CF  ...  pathologic_m  pathologic_n  pathologic_t
# cid                        ...
# aab1     7.45   6.4   4.7  ...             0             1             3
# aab4     8.10   5.8   5.7  ...             0             1             2
# aab6     7.20   6.4   3.0  ...             0             0             3
# aab8     8.00   5.8   5.1  ...             0             1             3
# aab9     7.65   6.7   4.4  ...             0             1             3
#
# [5 rows x 18474 columns]

# %%
col_meta_data.head()
# Out:
# chd                     sample_type  ...  year_of_tobacco_smoking_onset
# participant_id                       ...
# aab1            Primary solid Tumor  ...                         1962.0
# aab4            Primary solid Tumor  ...                            NaN
# aab6            Primary solid Tumor  ...                            NaN
# aab8            Primary solid Tumor  ...                            NaN
# aab9            Primary solid Tumor  ...                            NaN
#
# [5 rows x 82 columns]

# %%
data.head()
# Out:
# cid      aab1-Primary solid Tumor  ...  aapl-Primary solid Tumor
# rid                                ...
# SLC35E2                      7.45  ...                      9.05
# A1BG                         6.40  ...                      6.90
# A1CF                         4.70  ...                      2.00
# A2BP1                       -1.00  ...                       NaN
# A2LD1                        7.50  ...                      6.70
#
# [5 rows x 183 columns]

# %%
new_data = replaceMissingValues(data)

# %%
new_data.head()
# Out:
# cid      aab1-Primary solid Tumor  ...  aapl-Primary solid Tumor
# rid                                ...
# SLC35E2                      7.45  ...                  9.050000
# A1BG                         6.40  ...                  6.900000
# A1CF                         4.70  ...                  2.000000
# A2BP1                       -1.00  ...                  7.660113
# A2LD1                        7.50  ...                  6.700000
#
# [5 rows x 183 columns]

# %%
new_data.shape
# Out:
# (18465, 183)

# %%
#the data has 18465 genes and 183 samples

# %%
#calculating cdf and then ranking

# %%
import scipy
def calCDFAndRank(data):
  norm_cdf = scipy.stats.norm.cdf(data.values)
  _,id = np.unique(norm_cdf,return_inverse=True)
  out = (id.max() - id + 1).reshape(norm_cdf.shape)
  return out

# %%
for col in new_data:
  new_data[col] = calCDFAndRank(new_data[col])

# %%
new_data.head()
# Out:
# cid      aab1-Primary solid Tumor  ...  aapl-Primary solid Tumor
# rid                                ...
# SLC35E2                        10  ...                         1
# A1BG                           21  ...                        16
# A1CF                           38  ...                        65
# A2BP1                          88  ...                         8
# A2LD1                           9  ...                        18
#
# [5 rows x 183 columns]
